# %%
import math
pi = 22 / 7

# %%
math.sin(pi)
# Out:
# -0.00126448893037729

# %%
math.sin(pi/2)
# Out:
# 0.9999998001333682

# %%
math.cos(pi)
# Out:
# -0.999999200533553

# %%
math.cos(pi/2)
# Out:
# -0.000632244591553242

# %%
from math import * 
pi = 22/7

# %%
eval("sin(2*pi)**2 + cos(2*pi)**2")
# Out:
# 1.0

# %%
# %%writefile secret.txt
# helllo i am a secret variable
# Out:
# Writing secret.txt

# %%
eval("open('secret.txt').read()")
# Out:
# 'helllo i am a secret variable\n'

# %%
# %%writefile one.py
import tkinter as tk

root = tk.Tk()

def print_hello(name):
    print("hello world", name, flush=True)

b = tk.Button(root, text="Click Me", command=lambda name='Sachin yadav': print_hello(name))
#                                            None                                     
b.pack() 
    

root.mainloop()
# Out:
# Overwriting one.py

# %%
# !python one.py
# Out:
# hello world Sachin yadav
# hello world Sachin yadav
# hello world Sachin yadav
# hello world Sachin yadav

# %%
# cv2 -> opencv

# %%
import cv2

# %%
from PIL import Image

# %%
import matplotlib.pyplot as plt

# %%
#Image.open('tkinter_apps/images/sachin.jpg')

# %%
im = cv2.imread('tkinter_apps/images/sachin.jpg')
plt.imshow(im) # BGR, RGB
plt.show()
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGBA)
plt.imshow(im)
plt.show()
im = cv2.resize(im, (800, 600))

# BGR -> BlueGreenRed
# RBG -> RedBlueGreen

# %%
im.shape # 2045x2727
# Out:
# (600, 800, 4)

# %%
plt.imshow(im, )

# %%
im  = Image.fromarray(im)

# %%
plt.imshow(im)

# %%
#ipython console

# %%
capture = cv2.VideoCapture(1)

# %%
capture
# Out:
# <VideoCapture 000002095CAC5270>

# %%
capture.set(cv2.CAP_PROP_FRAME_HEIGHT, 800)
capture.set(cv2.CAP_PROP_FRAME_WIDTH, 600)
# Out:
# True

# %%
r, img = capture.read()

# %%
r
# Out:
# True

# %%
plt.imshow(img)

# %%
im = cv2.cvtColor(img, cv2.COLOR_BGR2RGBA)

# %%
plt.imshow(im)

# %%
plt.show()
