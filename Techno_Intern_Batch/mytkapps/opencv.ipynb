# %%
# opencv - machine vision
# pillow - image processing library

# %% [markdown]
#     if not installed than open your powershell window with admin privileges and run these commands
#
#     python -m pip install opencv-python
#
#     python -m pip install pillow

# %%
import cv2 # opencv
import PIL # python image library or PIL

# %%
# !ls mytkapps/images
# Out:
# corona.jpg
# myicon.ico
# one.gif

# %%
im = cv2.imread("mytkapps/images/corona.jpg")

# %%
print(type(im))
# Out:
# <class 'numpy.ndarray'>

# %%
im.shape
# Out:
# (438, 780, 3)

# %%
im[:3] # B  G  R
# Out:
# array([[[10, 10, 10],
#         [10, 10, 10],
#         [10, 10, 10],
#         ...,
#         [12, 12, 12],
#         [10, 10, 10],
#         [ 0,  0,  0]],
#
#        [[10, 10, 10],
#         [10, 10, 10],
#         [10, 10, 10],
#         ...,
#         [13, 13, 13],
#         [26, 26, 26],
#         [ 8,  8,  8]],
#
#        [[10, 10, 10],
#         [10, 10, 10],
#         [10, 10, 10],
#         ...,
#         [ 0,  0,  0],
#         [ 3,  3,  3],
#         [ 0,  0,  0]]], dtype=uint8)

# %%
import matplotlib.pyplot as plt

# %%
PIL.Image.open('mytkapps/images/corona.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=780x438 at 0x238E2BF0A48>

# %%
# 1920 x 1080 
# 1080 x 1920 x 3 

plt.imshow(im) # opencv -> BGR -> RBG
plt.show()

# %%
im = cv2.imread('mytkapps/images/corona.jpg')
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB) # BGR to RBG
plt.imshow(im)
plt.show()

# %%
from PIL.ImageTk import PhotoImage

# %%
im = cv2.imread('mytkapps/images/corona.jpg')
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB) # BGR to RBG
im = cv2.flip(im, 1)
im = cv2.resize(im, (400, 400))

img = PIL.Image.fromarray(im)

#img = PhotoImage(img)
plt.imshow(img)
plt.show()

# %%
im = cv2.imread('mytkapps/images/one.jpg')
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(im)
plt.show()

# %%
im  = cv2.flip(im, 0)
plt.imshow(im)
plt.show()

# %%
im  = cv2.flip(im, 1)
plt.imshow(im)
plt.show()

# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
device = cv2.VideoCapture(1)
# surface rear, front
#         0, 1
device.set(cv2.CAP_PROP_FRAME_WIDTH,3840)
device.set(cv2.CAP_PROP_FRAME_WIDTH,2160)
# Out:
# True

# %%
device
# Out:
# <VideoCapture 000001C9399E3F90>

# %%
b, im = device.read()

# %%
b
# Out:
# True

# %%
3840 x 2160
# Out:
#   File "<ipython-input-23-767af193fd27>", line 1
#     3840 x 2160
#          ^
# SyntaxError: invalid syntax

# %%
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
plt.imshow(im)

# %%
device.release()

# %%
im.shape
# Out:
# (480, 640, 3)

# %% [markdown]
# ### Data Science

# %% [markdown]
#     study of data to extract some meaningfull and usefull infromation out of structure, unstructure or semistructure data

# %% [markdown]
# Data Scientist
#
#     Curious: have ask relevent questions
#
#     Communication: should know how to tell a story using data
#
#     Mathematics: algebra, calcus, propbability, statistics, vectors & matrices
#
#     Programming: you should a language at intermediate level
#
#     Big Data: distributed computing, distributed storage, cloud computing
#
#     Algorithms: data models
#
#     ML, Deep Learning, AI -> basic understanding

# %% [markdown]
#     language -> python, r, scala, juila, java, js, c++

# %% [markdown]
# Data Science Tools
#
#
#     1. Data Management Tools
#
#         data collection, data warehousing, data gathering,
#
#         Data base -> mysql, posgresql, mariadb, mongodb, cassendra, couchdb,  ceph, hdfs , elastic search
#
#     2. Data Integration and Transformation Tools
#
#         data mining, data engineering, data pre-processing, ETL -> Extract Transform Load
#
#         SPARK, SQL, Apache Kafka
#
#     3. Data Visulation
#
#         graph plotation
#
#         *tableau, *powerbi, Hue, kibana, **GraphX
#
#     4. Model Deployment
#
#         Tensorflow servies, AWS, GCP, IBM Watson
#         PredictionIO, SELDON, **kubernetes, **openshift
#
#     5. Monitoring Tools
#
#         Prometheus, ModelDB
#
#     6. Code Asset Management
#
#         GIT, GITHUB, GITLAB, BITBUCKET

# %% [markdown]
#     Data Collections ?

# %% [markdown]
#     database
#
#     APIs
#
#     webscrapping

# %% [markdown]
#     Stats
